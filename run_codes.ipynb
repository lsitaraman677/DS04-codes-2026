# %%
# %run potatos/claude_shape.py
# Out:
# done

# %%
# %run potatos/shapeof2dpoints_normedfirst.py

# %%
# %run potatos/circlealgotests.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /global/u1/d/dionne/DS04-codes-2026/potatos/circlealgotests.py:59
#      57 import scipy.interpolate as interp
#      58 from scipy.stats import gaussian_kde
# ---> 59 from skimage import measure
#      61 def get_smooth_density_loop(points, percentage=100, grid_res=150, smooth_factor=0.05):
#      62     """
#      63     Generates a smooth, closed concave loop around a point cloud based on a percentage threshold.
#      64
#    (...)     69     - smooth_factor: smoothing intensity for the final spline
#      70     """
#
# ModuleNotFoundError: No module named 'skimage'

# %%
# %run traces/test_particle_traces.py
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /global/u1/d/dionne/DS04-codes-2026/traces/test_particle_traces.py:6
#       3 import sys
#       4 import numpy as np
# ----> 6 ts = OpenPMDTimeSeries(sys.argv[1])
#       8 n_particles = 10
#       9 newiters = np.array(ts.iterations)[np.linspace(0, len(ts.iterations)-1, 100, dtype=np.int32)]
#
# IndexError: list index out of range

# %%
# %run vecfields/vecfieldslices.py
# Out:
# loading data
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /global/u1/d/dionne/DS04-codes-2026/vecfields/vecfieldslices.py:17
#      13     return arr[*idxs]
#      15 print('loading data')
# ---> 17 vecs = OpenPMDTimeSeries(sys.argv[1])
#      18 pts = OpenPMDTimeSeries(sys.argv[2])
#      20 print('loaded data')
#
# IndexError: list index out of range

# %%
# %run traces/id_track.py whatever load traces/particles_in_cache
# Out:
# loading saved data
# enter video name:

# %%
# %run simple_explainers/single_particle_vec_field.py

# %%
# %run densityplots/
